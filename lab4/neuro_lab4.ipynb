# %% [markdown]
# # Лабораторная работа №4
#
# ## Сети с радиальными базисными элементами
#
# Целью работы является исследование свойств некоторых видов сетей с радиальными базисными элементами, алгоритмов обучения, а также применение сетей в задачах классификации и аппроксимации функции.

# %%
# import os
# os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1' 

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from tensorflow import keras
from tensorflow.keras import layers
from keras import backend

# %% [markdown]
# Сгенерирую псевдослучайные данные для обучения и тестирования.

# %%
def gen_random_ellipse_data(a, b, alpha, x_0, y_0, n):
    rand_nums = 2*np.pi*np.random.rand(n)
    x = x_0 + a * np.cos(rand_nums)
    y = y_0 + b * np.sin(rand_nums)
    xr = x * np.cos(alpha) - y * np.sin(alpha)
    yr = x * np.sin(alpha) + y * np.cos(alpha)
    return np.array([xr, yr])

# %%
fig, ax = plt.subplots(1, 1)
data1_size = 60
data2_size = 100
data3_size = 120
data1 = gen_random_ellipse_data(0.4, 0.5, 0, 0.05, 0, data1_size)
data2 = gen_random_ellipse_data(0.6, 0.6, 0, 0.00, 0, data2_size)
data3 = gen_random_ellipse_data(0.8, 1, 0, 0.05, 0, data3_size)
ax.scatter(data1[0], data1[1])
ax.scatter(data2[0], data2[1])
ax.scatter(data3[0], data3[1])

plt.show()

# %% [markdown]
# Перегруппирую и разобью данные на тестовую и обучающую выборку.

# %%
data = np.concatenate([data1, data2, data3], axis=1)
data = data.transpose()
labels1 = np.array([[1, 0, 0] for i in range(data1_size)])
labels2 = np.array([[0, 1, 0] for i in range(data2_size)])
labels3 = np.array([[0, 0, 1] for i in range(data3_size)])
labels = np.concatenate([labels1, labels2, labels3], axis=0)

X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.3, random_state=322)

# %% [markdown]
# Реализую радиально базисный слой, для построения нейросетевой модели.

# %%
class RBFLayer(layers.Layer):
    def __init__(self, output_dim, **kwargs):
        self.output_dim = output_dim
        super(RBFLayer, self).__init__(**kwargs)
        
    def build(self, input_shape):
        # print(input_shape)
        self.mu = self.add_weight(name='mu', 
                                  shape=(input_shape[1], self.output_dim), 
                                  initializer='uniform', 
                                  trainable=True)
        self.sigma = self.add_weight(name='sigma', 
                                     shape=(self.output_dim, ), 
                                     initializer='uniform', 
                                     trainable=True)
        super(RBFLayer, self).build(input_shape)
        
    def call(self, inputs):
        diff = backend.expand_dims(inputs) - self.mu
        return backend.exp(backend.sum(diff ** 2, axis=1) * self.sigma)

# %% [markdown]
# Построю и скомпилирую и обучу модель.

# %%
model = keras.models.Sequential()
model.add(RBFLayer(10, input_dim = 2))
model.add(keras.layers.Dense(3, activation='sigmoid'))

model.compile(loss='mse', optimizer='adam', metrics=['mae'])

# %%
epochs = 200
hist = model.fit(X_train, y_train, batch_size=5, epochs=epochs)
# Out:
# Epoch 1/200
# 40/40 [==============================] - 1s 4ms/step - loss: 0.2665 - mae: 0.4880
# Epoch 2/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2419 - mae: 0.4696
# Epoch 3/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.2247 - mae: 0.4550
# Epoch 4/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2136 - mae: 0.4424
# Epoch 5/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2078 - mae: 0.4330
# Epoch 6/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.2036 - mae: 0.4274
# Epoch 7/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.2005 - mae: 0.4228
# Epoch 8/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1974 - mae: 0.4183
# Epoch 9/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1943 - mae: 0.4136
# Epoch 10/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1913 - mae: 0.4086
# Epoch 11/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1885 - mae: 0.4042
# Epoch 12/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1856 - mae: 0.3998
# Epoch 13/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1828 - mae: 0.3953
# Epoch 14/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1800 - mae: 0.3932
# Epoch 15/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.1771 - mae: 0.3893
# Epoch 16/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.1740 - mae: 0.3850
# Epoch 17/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1710 - mae: 0.3796
# Epoch 18/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.1680 - mae: 0.3749
# Epoch 19/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1650 - mae: 0.3713
# Epoch 20/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.1619 - mae: 0.3676
# Epoch 21/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1588 - mae: 0.3622
# Epoch 22/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1557 - mae: 0.3577
# Epoch 23/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.1528 - mae: 0.3532
# Epoch 24/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1499 - mae: 0.3485
# Epoch 25/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1470 - mae: 0.3447
# Epoch 26/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1439 - mae: 0.3398
# Epoch 27/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1414 - mae: 0.3349
# Epoch 28/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1387 - mae: 0.3294
# Epoch 29/200
# 40/40 [==============================] - 0s 6ms/step - loss: 0.1359 - mae: 0.3253
# Epoch 30/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1334 - mae: 0.3205
# Epoch 31/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1309 - mae: 0.3164
# Epoch 32/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1289 - mae: 0.3128
# Epoch 33/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1264 - mae: 0.3086
# Epoch 34/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1242 - mae: 0.3042
# Epoch 35/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.1222 - mae: 0.2996
# Epoch 36/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1201 - mae: 0.2962
# Epoch 37/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1181 - mae: 0.2919
# Epoch 38/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1164 - mae: 0.2895
# Epoch 39/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1144 - mae: 0.2838
# Epoch 40/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1127 - mae: 0.2802
# Epoch 41/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1112 - mae: 0.2763
# Epoch 42/200
# 40/40 [==============================] - 0s 7ms/step - loss: 0.1098 - mae: 0.2735
# Epoch 43/200
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1081 - mae: 0.2704
# Epoch 44/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.1067 - mae: 0.2667
# Epoch 45/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.1052 - mae: 0.2633
# Epoch 46/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.1040 - mae: 0.2604
# Epoch 47/200
# 40/40 [==============================] - 0s 7ms/step - loss: 0.1027 - mae: 0.2573
# Epoch 48/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.1015 - mae: 0.2541
# Epoch 49/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1005 - mae: 0.2520
# Epoch 50/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0997 - mae: 0.2495
# Epoch 51/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0983 - mae: 0.2454
# Epoch 52/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0974 - mae: 0.2431
# Epoch 53/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0963 - mae: 0.2410
# Epoch 54/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0956 - mae: 0.2389
# Epoch 55/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0949 - mae: 0.2374
# Epoch 56/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0940 - mae: 0.2347
# Epoch 57/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0934 - mae: 0.2317
# Epoch 58/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0926 - mae: 0.2299
# Epoch 59/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0920 - mae: 0.2287
# Epoch 60/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0913 - mae: 0.2247
# Epoch 61/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0908 - mae: 0.2254
# Epoch 62/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0900 - mae: 0.2222
# Epoch 63/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0896 - mae: 0.2209
# Epoch 64/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0892 - mae: 0.2200
# Epoch 65/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0885 - mae: 0.2178
# Epoch 66/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0880 - mae: 0.2165
# Epoch 67/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0877 - mae: 0.2157
# Epoch 68/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0870 - mae: 0.2146
# Epoch 69/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0867 - mae: 0.2127
# Epoch 70/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0862 - mae: 0.2121
# Epoch 71/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0862 - mae: 0.2103
# Epoch 72/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0857 - mae: 0.2086
# Epoch 73/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0851 - mae: 0.2080
# Epoch 74/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0848 - mae: 0.2064
# Epoch 75/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0845 - mae: 0.2060
# Epoch 76/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0839 - mae: 0.2044
# Epoch 77/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0836 - mae: 0.2031
# Epoch 78/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0833 - mae: 0.2029
# Epoch 79/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0831 - mae: 0.2008
# Epoch 80/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0826 - mae: 0.2013
# Epoch 81/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0822 - mae: 0.1999
# Epoch 82/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0820 - mae: 0.1984
# Epoch 83/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0814 - mae: 0.1973
# Epoch 84/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0813 - mae: 0.1980
# Epoch 85/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0809 - mae: 0.1964
# Epoch 86/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0810 - mae: 0.1973
# Epoch 87/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0802 - mae: 0.1946
# Epoch 88/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0801 - mae: 0.1927
# Epoch 89/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0797 - mae: 0.1934
# Epoch 90/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0794 - mae: 0.1930
# Epoch 91/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0796 - mae: 0.1903
# Epoch 92/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0791 - mae: 0.1907
# Epoch 93/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0788 - mae: 0.1904
# Epoch 94/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0787 - mae: 0.1911
# Epoch 95/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0782 - mae: 0.1895
# Epoch 96/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0782 - mae: 0.1896
# Epoch 97/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0777 - mae: 0.1879
# Epoch 98/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0775 - mae: 0.1866
# Epoch 99/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0774 - mae: 0.1855
# Epoch 100/200
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0771 - mae: 0.1857
# Epoch 101/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0769 - mae: 0.1850
# Epoch 102/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0767 - mae: 0.1855
# Epoch 103/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0763 - mae: 0.1834
# Epoch 104/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0760 - mae: 0.1834
# Epoch 105/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0759 - mae: 0.1831
# Epoch 106/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0758 - mae: 0.1824
# Epoch 107/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0754 - mae: 0.1824
# Epoch 108/200
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0753 - mae: 0.1834
# Epoch 109/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0750 - mae: 0.1811
# Epoch 110/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0746 - mae: 0.1799
# Epoch 111/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0747 - mae: 0.1792
# Epoch 112/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0743 - mae: 0.1783
# Epoch 113/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0740 - mae: 0.1788
# Epoch 114/200
# 40/40 [==============================] - 0s 1ms/step - loss: 0.0737 - mae: 0.1789
# Epoch 115/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0735 - mae: 0.1788
# Epoch 116/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0734 - mae: 0.1766
# Epoch 117/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0733 - mae: 0.1778
# Epoch 118/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0733 - mae: 0.1762
# Epoch 119/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0727 - mae: 0.1755
# Epoch 120/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0726 - mae: 0.1762
# Epoch 121/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0724 - mae: 0.1755
# Epoch 122/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0721 - mae: 0.1745
# Epoch 123/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0719 - mae: 0.1731
# Epoch 124/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0717 - mae: 0.1728
# Epoch 125/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0715 - mae: 0.1718
# Epoch 126/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0722 - mae: 0.1757
# Epoch 127/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0715 - mae: 0.1709
# Epoch 128/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0711 - mae: 0.1729
# Epoch 129/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0709 - mae: 0.1709
# Epoch 130/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0707 - mae: 0.1700
# Epoch 131/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0706 - mae: 0.1719
# Epoch 132/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0702 - mae: 0.1708
# Epoch 133/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0702 - mae: 0.1710
# Epoch 134/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0700 - mae: 0.1685
# Epoch 135/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0698 - mae: 0.1682
# Epoch 136/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0697 - mae: 0.1679
# Epoch 137/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0695 - mae: 0.1690
# Epoch 138/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0692 - mae: 0.1667
# Epoch 139/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0690 - mae: 0.1671
# Epoch 140/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0688 - mae: 0.1668
# Epoch 141/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0687 - mae: 0.1662
# Epoch 142/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0686 - mae: 0.1660
# Epoch 143/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0685 - mae: 0.1659
# Epoch 144/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0689 - mae: 0.1644
# Epoch 145/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0679 - mae: 0.1647
# Epoch 146/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0679 - mae: 0.1654
# Epoch 147/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0676 - mae: 0.1644
# Epoch 148/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0675 - mae: 0.1637
# Epoch 149/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0673 - mae: 0.1634
# Epoch 150/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0672 - mae: 0.1626
# Epoch 151/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0671 - mae: 0.1625
# Epoch 152/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0670 - mae: 0.1619
# Epoch 153/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0667 - mae: 0.1639
# Epoch 154/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0666 - mae: 0.1623
# Epoch 155/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0664 - mae: 0.1614
# Epoch 156/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0664 - mae: 0.1607
# Epoch 157/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0658 - mae: 0.1611
# Epoch 158/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0659 - mae: 0.1608
# Epoch 159/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0658 - mae: 0.1598
# Epoch 160/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0655 - mae: 0.1583
# Epoch 161/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0653 - mae: 0.1592
# Epoch 162/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0655 - mae: 0.1600
# Epoch 163/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0650 - mae: 0.1579
# Epoch 164/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0649 - mae: 0.1571
# Epoch 165/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0648 - mae: 0.1589
# Epoch 166/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0648 - mae: 0.1570
# Epoch 167/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0647 - mae: 0.1576
# Epoch 168/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0645 - mae: 0.1572
# Epoch 169/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0643 - mae: 0.1564
# Epoch 170/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0640 - mae: 0.1548
# Epoch 171/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0639 - mae: 0.1542
# Epoch 172/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0637 - mae: 0.1553
# Epoch 173/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0636 - mae: 0.1547
# Epoch 174/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0634 - mae: 0.1540
# Epoch 175/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0634 - mae: 0.1544
# Epoch 176/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0634 - mae: 0.1551
# Epoch 177/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0630 - mae: 0.1529
# Epoch 178/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0629 - mae: 0.1535
# Epoch 179/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0629 - mae: 0.1539
# Epoch 180/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0625 - mae: 0.1520
# Epoch 181/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0624 - mae: 0.1522
# Epoch 182/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0622 - mae: 0.1507
# Epoch 183/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0621 - mae: 0.1507
# Epoch 184/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0619 - mae: 0.1516
# Epoch 185/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0619 - mae: 0.1506
# Epoch 186/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0619 - mae: 0.1491
# Epoch 187/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0614 - mae: 0.1507
# Epoch 188/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0615 - mae: 0.1503
# Epoch 189/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0613 - mae: 0.1495
# Epoch 190/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0612 - mae: 0.1493
# Epoch 191/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0613 - mae: 0.1503
# Epoch 192/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0609 - mae: 0.1493
# Epoch 193/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0607 - mae: 0.1477
# Epoch 194/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0604 - mae: 0.1477
# Epoch 195/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0604 - mae: 0.1456
# Epoch 196/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0605 - mae: 0.1485
# Epoch 197/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0602 - mae: 0.1463
# Epoch 198/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0601 - mae: 0.1464
# Epoch 199/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0602 - mae: 0.1457
# Epoch 200/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0598 - mae: 0.1466

# %% [markdown]
# Нарисую результаты.

# %%
steps = 200
x_span = np.linspace(-1.1, 1.1, steps)
y_span = np.linspace(-1.1, 1.1, steps)
xx, yy = np.meshgrid(x_span, y_span)
grid_points = np.array([xx.ravel(), yy.ravel()])
grid_points = grid_points.transpose()

grid_predictions = model(grid_points)
grid_labels = np.argmax(grid_predictions, axis=1)

predictions = model(X_test)

fig, ax = plt.subplots(1, 2, figsize=(15, 6))

grid_labels = grid_labels.reshape(xx.shape)
ax[0].contourf(xx, yy, grid_labels, alpha=0.5)
ax[0].scatter(X_test[:, 0], X_test[:, 1], c=np.argmax(y_test, axis=1))

mu_x = model.layers[0].get_weights()[0][0, :]
mu_y = model.layers[0].get_weights()[0][1, :]
ax[0].scatter(mu_x, mu_y, marker='P', color='red')

ax[1].plot(hist.history['loss'])

plt.show()

# %%
grid_predictions = model(grid_points).numpy().reshape(steps, steps, 3)

fig, ax = plt.subplots(1, 2, figsize=(15, 6))

ax[0].imshow(grid_predictions, extent=(-1.1, 1.1, -1.1, 1.1), alpha=0.7, origin='lower', aspect='auto', interpolation='bilinear')
ax[0].scatter(X_test[:, 0], X_test[:, 1], c=np.argmax(y_test, axis=1))

mu_x = model.layers[0].get_weights()[0][0, :]
mu_y = model.layers[0].get_weights()[0][1, :]
ax[0].scatter(mu_x, mu_y, marker='P', color='red')

ax[1].plot(hist.history['loss'])

plt.show()

# %% [markdown]
# ## Аппроксимация функции
#
# Аппроксимирую функцию с помощью нейросетевой модели с радиально базисными элементами.

# %%
def f(t):
    return np.sin(t**2-6*t+3)

x = np.arange(0, 5, 0.025)
y = f(x)

# %% [markdown]
# Построю и скомпилирую и обучу модель.

# %%
model = keras.models.Sequential()
model.add(RBFLayer(20, input_dim = 1))
model.add(keras.layers.Dense(20, activation='tanh'))
model.add(keras.layers.Dense(1, activation='linear'))

model.compile(loss='mse', optimizer='adam', metrics=['mae'])

# %%
epochs = 200
hist = model.fit(x, y, batch_size=1, epochs=epochs)
# Out:
# Epoch 1/200
# 200/200 [==============================] - 1s 2ms/step - loss: 0.3509 - mae: 0.4588
# Epoch 2/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3126 - mae: 0.4416
# Epoch 3/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2908 - mae: 0.4381
# Epoch 4/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2734 - mae: 0.4269
# Epoch 5/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2696 - mae: 0.4230
# Epoch 6/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2834 - mae: 0.4360
# Epoch 7/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2689 - mae: 0.4322
# Epoch 8/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2746 - mae: 0.4347
# Epoch 9/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2733 - mae: 0.4335
# Epoch 10/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2703 - mae: 0.4273
# Epoch 11/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2633 - mae: 0.4249
# Epoch 12/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2702 - mae: 0.4266
# Epoch 13/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2535 - mae: 0.4093
# Epoch 14/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2484 - mae: 0.4060
# Epoch 15/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2444 - mae: 0.4012
# Epoch 16/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2384 - mae: 0.3930
# Epoch 17/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2461 - mae: 0.3893
# Epoch 18/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2477 - mae: 0.4029
# Epoch 19/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2317 - mae: 0.3724
# Epoch 20/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2386 - mae: 0.3884
# Epoch 21/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2268 - mae: 0.3624
# Epoch 22/200
# 200/200 [==============================] - 1s 3ms/step - loss: 0.2308 - mae: 0.3687
# Epoch 23/200
# 200/200 [==============================] - 1s 3ms/step - loss: 0.2243 - mae: 0.3664
# Epoch 24/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2324 - mae: 0.3715
# Epoch 25/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2978 - mae: 0.4448
# Epoch 26/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2334 - mae: 0.3624
# Epoch 27/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2125 - mae: 0.3402
# Epoch 28/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2223 - mae: 0.3393
# Epoch 29/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2178 - mae: 0.3453
# Epoch 30/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2104 - mae: 0.3382
# Epoch 31/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2242 - mae: 0.3546
# Epoch 32/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2153 - mae: 0.3508
# Epoch 33/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2003 - mae: 0.3221
# Epoch 34/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2007 - mae: 0.3251
# Epoch 35/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.1903 - mae: 0.3250
# Epoch 36/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1806 - mae: 0.3102
# Epoch 37/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1732 - mae: 0.3105
# Epoch 38/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.1835 - mae: 0.3246
# Epoch 39/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.1600 - mae: 0.3120
# Epoch 40/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1318 - mae: 0.2698
# Epoch 41/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.1201 - mae: 0.2537
# Epoch 42/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0858 - mae: 0.2114
# Epoch 43/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0770 - mae: 0.2038
# Epoch 44/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0859 - mae: 0.2138
# Epoch 45/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0616 - mae: 0.1891
# Epoch 46/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0688 - mae: 0.1839
# Epoch 47/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0509 - mae: 0.1536
# Epoch 48/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0509 - mae: 0.1574
# Epoch 49/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0400 - mae: 0.1316
# Epoch 50/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0491 - mae: 0.1471
# Epoch 51/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0358 - mae: 0.1232
# Epoch 52/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0465 - mae: 0.1454
# Epoch 53/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0373 - mae: 0.1243
# Epoch 54/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0618 - mae: 0.1599
# Epoch 55/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0426 - mae: 0.1339
# Epoch 56/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0335 - mae: 0.1192
# Epoch 57/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0603 - mae: 0.1641
# Epoch 58/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0432 - mae: 0.1302
# Epoch 59/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0413 - mae: 0.1288
# Epoch 60/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0653 - mae: 0.1629
# Epoch 61/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0377 - mae: 0.1268
# Epoch 62/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0338 - mae: 0.1151
# Epoch 63/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0362 - mae: 0.1217
# Epoch 64/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0286 - mae: 0.1029
# Epoch 65/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0303 - mae: 0.1088
# Epoch 66/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0347 - mae: 0.1185
# Epoch 67/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0241 - mae: 0.0948
# Epoch 68/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0300 - mae: 0.1071
# Epoch 69/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0470 - mae: 0.1376
# Epoch 70/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0376 - mae: 0.1138
# Epoch 71/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0300 - mae: 0.1071
# Epoch 72/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0343 - mae: 0.1227
# Epoch 73/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0235 - mae: 0.0938
# Epoch 74/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0204 - mae: 0.0832
# Epoch 75/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0207 - mae: 0.0836
# Epoch 76/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0187 - mae: 0.0793
# Epoch 77/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0217 - mae: 0.0865
# Epoch 78/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0192 - mae: 0.0864
# Epoch 79/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0183 - mae: 0.0832
# Epoch 80/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0215 - mae: 0.0940
# Epoch 81/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0201 - mae: 0.0838
# Epoch 82/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0291 - mae: 0.1061
# Epoch 83/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0197 - mae: 0.0896
# Epoch 84/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0258 - mae: 0.0985
# Epoch 85/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0149 - mae: 0.0715
# Epoch 86/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0253 - mae: 0.1022
# Epoch 87/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0211 - mae: 0.0875
# Epoch 88/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0175 - mae: 0.0849
# Epoch 89/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0168 - mae: 0.0825
# Epoch 90/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0159 - mae: 0.0737
# Epoch 91/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0323 - mae: 0.1136
# Epoch 92/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0190 - mae: 0.0902
# Epoch 93/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0268 - mae: 0.1070
# Epoch 94/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0181 - mae: 0.0894
# Epoch 95/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0144 - mae: 0.0785
# Epoch 96/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0149 - mae: 0.0802
# Epoch 97/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0142 - mae: 0.0757
# Epoch 98/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0214 - mae: 0.0956
# Epoch 99/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0256 - mae: 0.1049
# Epoch 100/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0182 - mae: 0.0801
# Epoch 101/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0115 - mae: 0.0699
# Epoch 102/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0141 - mae: 0.0812
# Epoch 103/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0113 - mae: 0.0687
# Epoch 104/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0123 - mae: 0.0709
# Epoch 105/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0144 - mae: 0.0754
# Epoch 106/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0134 - mae: 0.0714
# Epoch 107/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0285 - mae: 0.1005
# Epoch 108/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0121 - mae: 0.0709
# Epoch 109/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0119 - mae: 0.0711
# Epoch 110/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0202 - mae: 0.0928
# Epoch 111/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0100 - mae: 0.0643
# Epoch 112/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0098 - mae: 0.0617
# Epoch 113/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0092 - mae: 0.0616
# Epoch 114/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0094 - mae: 0.0617
# Epoch 115/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0107 - mae: 0.0667
# Epoch 116/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0103 - mae: 0.0645
# Epoch 117/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0135 - mae: 0.0747
# Epoch 118/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0103 - mae: 0.0691
# Epoch 119/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0117 - mae: 0.0744
# Epoch 120/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0107 - mae: 0.0685
# Epoch 121/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0095 - mae: 0.0604
# Epoch 122/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0098 - mae: 0.0630
# Epoch 123/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0124 - mae: 0.0772
# Epoch 124/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0201 - mae: 0.0894
# Epoch 125/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0306 - mae: 0.0868
# Epoch 126/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0088 - mae: 0.0583
# Epoch 127/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0073 - mae: 0.0538
# Epoch 128/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0076 - mae: 0.0563
# Epoch 129/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0068 - mae: 0.0494
# Epoch 130/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0062 - mae: 0.0474
# Epoch 131/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0256 - mae: 0.0841
# Epoch 132/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0059 - mae: 0.0494
# Epoch 133/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0054 - mae: 0.0449
# Epoch 134/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0055 - mae: 0.0455
# Epoch 135/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0049 - mae: 0.0422
# Epoch 136/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0048 - mae: 0.0425
# Epoch 137/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0049 - mae: 0.0406
# Epoch 138/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0070 - mae: 0.0507
# Epoch 139/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0044 - mae: 0.0392
# Epoch 140/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0115 - mae: 0.0572
# Epoch 141/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0038 - mae: 0.0375
# Epoch 142/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0036 - mae: 0.0373
# Epoch 143/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0046 - mae: 0.0424
# Epoch 144/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0040 - mae: 0.0371
# Epoch 145/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0100 - mae: 0.0566
# Epoch 146/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0057 - mae: 0.0489
# Epoch 147/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0041 - mae: 0.0383
# Epoch 148/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0064 - mae: 0.0447
# Epoch 149/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0024 - mae: 0.0297
# Epoch 150/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0024 - mae: 0.0282
# Epoch 151/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0052 - mae: 0.0458
# Epoch 152/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0050 - mae: 0.0450
# Epoch 153/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0050 - mae: 0.0423
# Epoch 154/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0034 - mae: 0.0362
# Epoch 155/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0026 - mae: 0.0318
# Epoch 156/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0023 - mae: 0.0305
# Epoch 157/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0023 - mae: 0.0327
# Epoch 158/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0045 - mae: 0.0434
# Epoch 159/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0097 - mae: 0.0544
# Epoch 160/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0035 - mae: 0.0367
# Epoch 161/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0029 - mae: 0.0332
# Epoch 162/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0022 - mae: 0.0312
# Epoch 163/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0042 - mae: 0.0387
# Epoch 164/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0030 - mae: 0.0347
# Epoch 165/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0024 - mae: 0.0357
# Epoch 166/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0038 - mae: 0.0385
# Epoch 167/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0109 - mae: 0.0583
# Epoch 168/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0020 - mae: 0.0284
# Epoch 169/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0020 - mae: 0.0318
# Epoch 170/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0015 - mae: 0.0254
# Epoch 171/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0026 - mae: 0.0338
# Epoch 172/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0021 - mae: 0.0284
# Epoch 173/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0069 - mae: 0.0503
# Epoch 174/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0020 - mae: 0.0296
# Epoch 175/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0040 - mae: 0.0389
# Epoch 176/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0030 - mae: 0.0336
# Epoch 177/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0018 - mae: 0.0315
# Epoch 178/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0015 - mae: 0.0257
# Epoch 179/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0086 - mae: 0.0548
# Epoch 180/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0017 - mae: 0.0294
# Epoch 181/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0022 - mae: 0.0327
# Epoch 182/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0055 - mae: 0.0434
# Epoch 183/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0025 - mae: 0.0326
# Epoch 184/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0010 - mae: 0.0237
# Epoch 185/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0013 - mae: 0.0252
# Epoch 186/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0019 - mae: 0.0287
# Epoch 187/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0031 - mae: 0.0381
# Epoch 188/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0018 - mae: 0.0256
# Epoch 189/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0038 - mae: 0.0343
# Epoch 190/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0050 - mae: 0.0380
# Epoch 191/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0018 - mae: 0.0291
# Epoch 192/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0013 - mae: 0.0247
# Epoch 193/200
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0102 - mae: 0.0635
# Epoch 194/200
# 200/200 [==============================] - 0s 2ms/step - loss: 9.7983e-04 - mae: 0.0224
# Epoch 195/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0012 - mae: 0.0240
# Epoch 196/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0032 - mae: 0.0356
# Epoch 197/200
# 200/200 [==============================] - 0s 2ms/step - loss: 7.6598e-04 - mae: 0.0189
# Epoch 198/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0022 - mae: 0.0311
# Epoch 199/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0023 - mae: 0.0346
# Epoch 200/200
# 200/200 [==============================] - 0s 2ms/step - loss: 9.9738e-04 - mae: 0.0225

# %% [markdown]
# Нарисую результаты.

# %%
x = np.arange(0, 5, 0.025/4)

predictions = model(x)

fig, ax = plt.subplots(1, 2, figsize=(15, 6))
ax[0].plot(x, f(x))
ax[0].plot(x, predictions)

ax[1].plot(hist.history['loss'])

plt.show()

# %% [markdown]
# __Вывод__: в ходе выполнения лабораторной работы я реализовал радиально базисный слой и с помощью него построил нейросетевые модели для классификации объектов и аппроксимации функции. Обучил обе модели и убедился, что сети с радиально базисными элементами могут быть продуктивными для решения задач классификации при линейной неразделимости выборки и аппроксимации функции.
